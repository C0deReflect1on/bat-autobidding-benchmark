# %%
import pandas as pd

# %%
campaigns = pd.read_csv("hf://datasets/AvitoTech/BAT/fpa/campaigns.csv")

# %%
campaigns.to_csv('campaigns.csv')

# %%
stats = pd.read_csv("hf://datasets/AvitoTech/BAT/fpa/stats.csv")

# %%
stats.to_csv('stats.csv')

# %%
import pandas as pd

# %%
campaigns = pd.read_csv("../data/fpa/campaigns.csv")

# %%
stats = pd.read_csv("../data/fpa/stats.csv")

# %%
stats.head(5)
# Out:
#    Unnamed: 0  campaign_id     period     item_id  contact_price_bin  \
# 0           0     76078451  529786800  4229093900               48.0
# 1           1     76230675  529790400  4012186500               42.0
# 2           2     74435084  529740000   294430500               45.0
# 3           3     74119310  529761600   485836300               47.0
# 4           4     76305696  529779600   625172200               54.0
#
#    AuctionVisibilitySurplus  AuctionClicksSurplus  AuctionContactsSurplus  \
# 0                 12.077467              0.380174                0.024912
# 1                 10.316097              0.930837                0.041039
# 2                  4.110070              0.406913                0.021576
# 3                  0.673043              0.026266                0.001173
# 4                  1.491969              0.113333                0.005261
#
#    AuctionWinBidSurplus  CTRPredicts  CRPredicts  AuctionCount  \
# ...

# %%
subset_campaigns = campaigns['campaign_id'].iloc[:10000]

# %%
subset_campaigns_df = campaigns[campaigns['campaign_id'].isin(subset_campaigns)]
subset_campaigns_df.to_csv('../data/small_example/fpa/subsample_campaigns.csv')
subset_stats_df = stats[stats['campaign_id'].isin(subset_campaigns)]
subset_stats_df.to_csv('../data/small_example/fpa/subsample_stats.csv')
