# %% [markdown]
# # 03 May 05 Default Linear Clip + DQN LayerNorm
#
# Keeps the tuned LinearBidder bin clip fixed and tests DQN LayerNorm against the fixed-clip default control.

# %%
import sys
import json
import pickle
from dataclasses import replace
from pathlib import Path

import pandas as pd

cwd = Path.cwd().resolve()
REPO_ROOT = cwd
while REPO_ROOT != REPO_ROOT.parent and not (REPO_ROOT / 'pyproject.toml').exists():
    REPO_ROOT = REPO_ROOT.parent
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from example_notebooks.experiments.drlb.profiles import build_config as build_drlb_config
from example_notebooks.experiments.drlb.profiles import get_profile as get_drlb_profile
from example_notebooks.experiments.shared_runner import run_experiment_inprocess

# %%
_linear_scr_fpa = Path(REPO_ROOT) / 'example_notebooks' / 'evaluate_baselines' / 'best_params' / 'fpa_baseline_n10_rndm_42' / 'linear_scr_FPA.pkl'
with _linear_scr_fpa.open('rb') as f:
    linear_tuned_params = pickle.load(f)
linear_tuned_params
# Out:
# {'coef': 0.023335213830958296,
#  'lower_clip': 9,
#  'upper_clip': 1,
#  'factor': 3.4224852046754637}

# %%
RUN_NAME = 'may06_default_clip_dqn_layer_norm_fixed'
DRLB_PROFILE = 'may05_default_clip_dqn_layer_norm_fixed'
VERBOSE = False

# %%
config = build_drlb_config(RUN_NAME, profile=DRLB_PROFILE, split_set='full_train_val_holdout')
config = replace(config, n_trials=1, refit_on='train_plus_val', max_steps=None)

profile_data = get_drlb_profile(DRLB_PROFILE)
base_drlb_params = dict(profile_data['base_drlb_params'])
reference_model_params = dict(profile_data['reference_model_params'])
base_drlb_params['bid_lower_clip'] = 3
base_drlb_params['bid_upper_clip'] = 8
base_drlb_params['traffic_path'] = str(REPO_ROOT / 'data' / 'traffic_share.csv')

result = run_experiment_inprocess(
    config,
    verbose=VERBOSE,
    base_drlb_params=base_drlb_params,
    reference_model_params=reference_model_params,
    state_type=profile_data['state_type'],
    objective=profile_data['objective'],
    search_space_fn=profile_data['search_space_fn'],
    n_trials=config.n_trials,
    max_train_steps=config.max_steps,
)

summary = result['summary']
{
    'run_name': config.run_name,
    'profile': DRLB_PROFILE,
    'linear_tuned_params': linear_tuned_params,
    'base_drlb_params': base_drlb_params,
    'reference_model_params': reference_model_params,
    'best_val_metrics': summary['tuning']['best_val_metrics'],
    'final_holdout_metrics': summary['final_holdout']['metrics'],
    'diagnostics_png': summary['refit']['combined_diagnostics_plot_path'],
}
# Out:
# [I 2026-05-06 01:14:30,481] A new study created in memory with name: no-name-ee2e55ec-f934-42f3-971a-ba0bb8b7e72b
# [I 2026-05-06 01:18:40,984] Trial 0 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:23:00,203] Trial 1 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:26:54,275] Trial 2 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:30:42,020] Trial 3 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:34:28,505] Trial 4 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:38:16,933] Trial 5 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:42:05,774] Trial 6 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:45:58,873] Trial 7 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 01:49:48,940] Trial 8 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# [I 2026-05-06 05:44:23,928] Trial 9 finished with value: 2075.548926142401 and parameters: {'dqn_lr': 0.0003, 'reward_net_lr': 0.01, 'bid_lower_clip': 9, 'bid_upper_clip': 1}. Best is trial 0 with value: 2075.548926142401.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       8 base_drlb_params['bid_upper_clip'] = 8
#       9 base_drlb_params['traffic_path'] = str(REPO_ROOT / 'data' / 'traffic_share.csv')
# ---> 11 result = run_experiment_inprocess(
#      12     config,
#      13     verbose=VERBOSE,
#      14     base_drlb_params=base_drlb_params,
#      15     reference_model_params=reference_model_params,
#      16     state_type=profile_data['state_type'],
#      17     objective=profile_data['objective'],
#      18     search_space_fn=profile_data['search_space_fn'],
#      19     n_trials=config.n_trials,
#      20     max_train_steps=config.max_steps,
#      21 )
#      23 summary = result['summary']
#      24 {
#      25     'run_name': config.run_name,
#      26     'profile': DRLB_PROFILE,
#    (...)     32     'diagnostics_png': summary['refit']['combined_diagnostics_plot_path'],
#      33 }
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/example_notebooks/experiments/shared_runner.py:70, in run_experiment_inprocess(config, verbose, **family_kwargs)
#      64 def run_experiment_inprocess(
#      65     config,
#      66     *,
#      67     verbose: bool = False,
#      68     **family_kwargs: Any,
#      69 ) -> dict[str, Any]:
# ---> 70     return run_family(
#      71         config,
#      72         mode="inprocess",
#      73         verbose=verbose,
#      74         family_kwargs=family_kwargs,
#      75     )
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/example_notebooks/experiments/shared_runner.py:42, in run_family(config, mode, verbose, family_kwargs)
#      40 normalized_splits = resolve_normalized_splits(config)
#      41 initialize_runtime_seeds(config.seeds)
# ---> 42 return runners[mode](
#      43     config,
#      44     normalized_splits,
#      45     verbose=verbose,
#      46     **family_kwargs,
#      47 )
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/example_notebooks/experiments/adapters/drlb_adapter.py:197, in run_drlb_experiment_inprocess(config, normalized_splits, base_drlb_params, reference_model_params, state_type, objective, search_space_fn, n_trials, max_train_steps, verbose, show_progress)
#     188 best_trial_params = dict(best_trial_run["params"])
#     190 best_val_bidder_params = {
#     191     **best_trial_params,
#     192     "state_type": state_type,
#    (...)    195     "use_tqdm": progress_enabled,
#     196 }
# --> 197 best_val_run = run_drlb_candidate(
#     198     config=config,
#     199     data_splits=normalized_splits,
#     200     train_stats_df=train_stats_df,
#     201     train_campaigns_df=train_campaigns_df,
#     202     label="best_val",
#     203     bidder_params=best_val_bidder_params,
#     204     eval_split_key="val",
#     205     objective=objective,
#     206     max_train_steps=max_train_steps,
#     207     verbose=verbose,
#     208     show_progress=progress_enabled,
#     209     scratch_dir=tmpdir_path,
#     210     return_bidder=True,
#     211     return_diagnostics=True,
#     212     write_artifacts=False,
#     213 )
#     215 refit_stats_df, refit_campaigns_df = load_refit_training_frames(
#     216     config=config,
#     217     normalized_splits=normalized_splits,
#     218 )
#     219 best_refit_run = run_drlb_candidate(
#     220     config=config,
#     221     data_splits=normalized_splits,
#    (...)    234     write_artifacts=False,
#     235 )
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/example_notebooks/experiments/adapters/drlb_adapter.py:354, in run_drlb_candidate(config, data_splits, train_stats_df, train_campaigns_df, label, bidder_params, eval_split_key, objective, max_train_steps, verbose, show_progress, scratch_dir, return_bidder, return_diagnostics, write_artifacts)
#     335 def run_drlb_candidate(
#     336     config,
#     337     data_splits: dict[str, dict[str, str]],
#    (...)    351     write_artifacts: bool = True,
#     352 ) -> dict[str, Any]:
#     353     bidder = DRLBBidder(bidder_params)
# --> 354     bidder.fit(
#     355         train_stats_df,
#     356         campaigns_df=train_campaigns_df,
#     357         max_steps=max_train_steps,
#     358         objective=objective,
#     359     )
#     361     diagnostics = bidder.get_training_diagnostics().copy()
#     362     model_path = scratch_dir / f"{label}.pt"
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/simulator/model/drlb_bidder.py:524, in DRLBBidder.fit(self, stats_df, campaigns_df, max_steps, objective)
#     522 rnet_reward = self.agent.predict_reward(state_before_action, action_beta)
#     523 # Algorithm 2, step 5: update DQN with RewardNet-predicted reward for (s_t, a_t).
# --> 524 self.agent.learn_dqn_transition(
#     525     state_before_action,
#     526     action_idx,
#     527     rnet_reward,
#     528     state_after_outcome,
#     529     done=done,
#     530 )
#     532 # Algorithm 2, step 6: train RewardNet from immediate reward / episode target mode.
#     533 self.agent.record_reward_net_step(state_before_action, action_beta, immediate_reward)
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/simulator/model/drlb/rl_bid_agent_bat.py:115, in RlBidAgent.learn_dqn_transition(self, state_before_action, action_idx, rnet_reward, state_after_outcome, done)
#     114 def learn_dqn_transition(self, state_before_action, action_idx, rnet_reward, state_after_outcome, done=False):
# --> 115     self.dqn_agent.step(
#     116         state_before_action,
#     117         action_idx,
#     118         rnet_reward,
#     119         state_after_outcome,
#     120         done=done,
#     121     )
#     122     self.dqn_action = int(action_idx)
#     123     self.rnet_r = float(rnet_reward)
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/simulator/model/drlb/dqn.py:112, in DQN.step(self, state, action, reward, next_state, done)
#     110 if len(self.memory) > self.batch_size:
#     111     experiences = self.memory.sample()
# --> 112     self.learn(experiences, self.gamma)
#
# File ~/code/local_ml/rl/bat-autobidding-benchmark/simulator/model/drlb/dqn.py:166, in DQN.learn(self, experiences, gamma)
#     164 if self.grad_clip_norm is not None:
#     165     torch.nn.utils.clip_grad_norm_(self.qnetwork_local.parameters(), self.grad_clip_norm)
# --> 166 self.optimizer.step()
#     167 if self.scheduler is not None:
#     168     self.scheduler.step()
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/optimizer.py:533, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     528             raise RuntimeError(
#     529                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     530             )
#     532 # pyrefly: ignore [invalid-param-spec]
# --> 533 out = func(*args, **kwargs)
#     534 self._optimizer_step_code()
#     536 # call optimizer step post hooks
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/optimizer.py:151, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     149     return disabled_func(*args, **kwargs)
#     150 else:
# --> 151     return func(*args, **kwargs)
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/adam.py:971, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     968 else:
#     969     func = _single_tensor_adam
# --> 971 func(
#     972     params,
#     973     grads,
#     974     exp_avgs,
#     975     exp_avg_sqs,
#     976     max_exp_avg_sqs,
#     977     state_steps,
#     978     amsgrad=amsgrad,
#     979     has_complex=has_complex,
#     980     beta1=beta1,
#     981     beta2=beta2,
#     982     lr=lr,
#     983     weight_decay=weight_decay,
#     984     eps=eps,
#     985     maximize=maximize,
#     986     capturable=capturable,
#     987     differentiable=differentiable,
#     988     grad_scale=grad_scale,
#     989     found_inf=found_inf,
#     990     decoupled_weight_decay=decoupled_weight_decay,
#     991 )
#
# File ~/code/local_ml/rl/bat_venv/lib/python3.11/site-packages/torch/optim/adam.py:545, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     543         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     544     else:
# --> 545         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     547     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     549 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
pd.DataFrame([
    {'artifact': 'run_summary_json', 'path': str(config.outputs_dir / 'run_summary.json')},
    {'artifact': 'metrics_json', 'path': str(config.outputs_dir / 'metrics.json')},
    {'artifact': 'drlb_diagnostics_png', 'path': str(config.outputs_dir / 'drlb_diagnostics.png')},
    {'artifact': 'best_refit_model', 'path': str(config.best_models_dir / 'best_refit.pt')},
])
# Out:
#                artifact                                               path
# 0      run_summary_json  /Users/amsafin/code/local_ml/rl/bat-autobiddin...
# 1          metrics_json  /Users/amsafin/code/local_ml/rl/bat-autobiddin...
# 2  drlb_diagnostics_png  /Users/amsafin/code/local_ml/rl/bat-autobiddin...
# 3      best_refit_model  /Users/amsafin/code/local_ml/rl/bat-autobiddin...
